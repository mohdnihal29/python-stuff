# %%
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#creating a graph object
G = nx.barabasi_albert_graph(100,10)

# %%
nx.draw_spring(G)

# %%
plt.hist([v for k,v in nx.degree(G)])
# Out:
# (array([30., 27., 16., 12.,  6.,  3.,  2.,  2.,  1.,  1.]),
#  array([ 7. , 11.8, 16.6, 21.4, 26.2, 31. , 35.8, 40.6, 45.4, 50.2, 55. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(nx.centrality.closeness_centrality(G).values())
# Out:
# (array([11., 30., 20., 13., 15.,  4.,  3.,  2.,  1.,  1.]),
#  array([0.47596154, 0.49759615, 0.51923077, 0.54086538, 0.5625    ,
#         0.58413462, 0.60576923, 0.62740385, 0.64903846, 0.67067308,
#         0.69230769]),
#  <a list of 10 Patch objects>)

# %%
 nx.diameter(G)
# Out:
# 3

# %%
nx.cluster.average_clustering(G)
# Out:
# 0.2863874113372673

# %%
#pandas

# %%
nodes = list(range(100))
df = pd.DataFrame({'from': np.random.choice(nodes, 100), 'to': np.random.choice(nodes, 100)})

# %%
df
# Out:
#     from  to
# 0     40  66
# 1     93  60
# 2     32  47
# 3     74  92
# 4     17  67
# ..   ...  ..
# 95    38   3
# 96    71  61
# 97     3  37
# 98    75  56
# 99     9  80
#
# [100 rows x 2 columns]

# %%
G = nx.from_pandas_edgelist(df, source='from', target='to')
nx.draw(G)
